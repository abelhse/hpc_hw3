# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pathlib
out_file = pathlib.Path('./slurm-2319056.out')

# %%
res = []
with open(out_file, 'rt') as f:
    content = f.read()
i = content.find('maxAbsErr')
content = content[i:]
d = {}
for line in content.split('\n'):
    a= line.split('=')
    if len(a) == 1:
        continue
    k, v = a
    d[k] = v
# print(d)
d['x'] = np.fromstring(d['x'], sep=' ')
d['u'] = np.fromstring(d['u'], sep=' ')
d['u_true'] = np.fromstring(d['u_true'], sep=' ')
d['filename'] = str(out_file)
d['block_sizes'] = np.asarray(list(map(int, d['block_sizes'].split())))

import json
print(content)
# break
# Out:
# maxAbsErr=0.0360803
# size=4
# Nx_global=51
# Nt=501
# T=0.1
# tau=0.0002
# h=0.02
# totalTime=0.00209678
# algo=1
# block_sizes=13 13 13 12
# u=0.0307757 0.0615514 0.091876 0.122201 0.15163 0.18106 0.209164 0.237267 0.263635 0.290003 0.31425 0.338497 0.360271 0.382045 0.40103 0.420015 0.435935 0.451856 0.464484 0.477111 0.486262 0.495414 0.500958 0.506502 0.508358 0.510215 0.508358 0.506502 0.500958 0.495414 0.486262 0.477111 0.464484 0.451856 0.435935 0.420015 0.40103 0.382045 0.360271 0.338497 0.31425 0.290003 0.263635 0.237267 0.209164 0.18106 0.15163 0.122201 0.091876 0.0615514 0.0307757
# u_true=0 0.029808 0.0594981 0.0889527 0.118055 0.146691 0.174745 0.202109 0.228673 0.254333 0.278987 0.302539 0.324895 0.345967 0.365673 0.383934 0.40068 0.415844 0.429368 0.441197 0.451286 0.459595 0.466091 0.47075 0.473552 0.474487 0.473552 0.47075 0.466091 0.459595 0.451286 0.441197 0.429368 0.415844 0.40068 0.383934 0.365673 0.345967 0.324895 0.302539 0.278987 0.254333 0.228673 0.202109 0.174745 0.14669 0.118055 0.0889526 0.0594981 0.029808 -4.14876e-08
# x=0 0.02 0.04 0.06 0.08 0.1 0.12 0.14 0.16 0.18 0.2 0.22 0.24 0.26 0.28 0.3 0.32 0.34 0.36 0.38 0.4 0.42 0.44 0.46 0.48 0.5 0.52 0.54 0.56 0.58 0.6 0.62 0.64 0.66 0.68 0.7 0.72 0.74 0.76 0.78 0.8 0.82 0.84 0.86 0.88 0.9 0.92 0.94 0.96 0.98 1

# %%
# for j in range(0, u.shape[0], int(u.shape[0] / 10)):
j=0
plt.plot(d['x'], d['u'], ls='--', marker='x', c='red', label='numerical')
plt.plot(d['x'], d['u_true'] , marker='x', c='gray', label='formula')
plt.ylabel('u')
plt.xlabel('x')
plt.legend()
plt.title(f'Nx = {d["Nx_global"]}, Nt={d["Nt"]}')
# Out:
# Text(0.5, 1.0, 'Nx = 51, Nt=501')
